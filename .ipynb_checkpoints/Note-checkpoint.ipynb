# %% [markdown]
# # DTF. Взаимодействие.

# %%
from DTF_API import DTF
import asyncio

dtf = DTF(token = "79a24dbb2334b0a52a506db13f561cc006a6c2b52c12ed5ce2850eb5dd86a583")

# %% [markdown]
#  Методы работают все, но метод получения новых комментариев работает с багом: присылает только последний комментарий от определенного пользователя к записи. (С чем я сейчас и разбирался)

# %%
"""
        Метод получения всех своих постов по данному токену.
"""
await dtf.get_all_my_entries()
# Out:
# {'message': [{'id': 1612676,
#    'title': 'Этап авторизации + запрос пройден',
#    'intro': 'Ипользуя библиотеку requests',
#    'comments_id': {22484013,
#     22485169,
#     22485197,
#     23295777,
#     23299994,
#     23299997,
#     23300181,
#     23300405,
#     23300489,
#     23300495,
#     23300508,
#     23300509,
#     23300540,
#     23300541,
#     23300561,
#     23300563,
#     23308743,
#     23308785,
#     23308787,
#     23308788,
#     23308802,
#     23376470,
#     23376507,
#     23376515,
#     23376549}},
#   {'id': 1612527,
#    'title': 'Hello world',
#    'intro': 'Первые шажки по парсу dtf.',
#    'comments_id': {22482162,
#     22482210,
#     22482537,
#     22482850,
#     22483137,
#     22484009,
#     22484033,
#     22484126,
#     22484144,
#     23232401,
#     23232478,
#     23295256,
#     23295261,
#     23295929,
#     23295938,
#     23295970,
#     23295992,
#     23295997,
#     23296896,
#     23297058,
#     23297063,
#     23297067,
#     23300006,
#     23300011,
#     23300015,
#     23300123,
#     23300125,
#     23300515,
#     23300516,
#     23300530,
#     23300535,
#     23300564,
#     23300566,
#     23300580,
#     23300581,
#     23300586,
#     23300588,
#     23300632,
#     23300634,
#     23300657,
#     23300658,
#     23300664,
#     23300668,
#     23300670,
#     23308814}}]}

# %%
"""
    Метод получения всех комментариев к посту по его id.
"""
# as an example we can use my entry Первые шажки 

posts = await dtf.get_comments_by_post_id(1612676)
print(posts)

#Другое представление
posts = await dtf.get_comments_by_post_id(1612676)
print(posts.get_all_comments_as_dict())
#Здесь такое возможно из за использования CommentTree
# Out:
# Syhapod: В полигон иди, тебе уже кидали <|endofstatement|>
# Котьмак из школы кота: Дарю: <|endofstatement|>
# Котьмак из школы кота: И в общей ленте не мусоришь, и за тем куда постишь следить не надо, и от лишних телодвижений по занесению тебя в чс окружающих избавляешь
# Сплошные плюсы <|endofstatement|>
# Artem Glechinsky: zczxc <|endofstatement|>
# Artem Glechinsky: sdfsf <|endofstatement|>
# Artem Glechinsky: Apchi <|endofstatement|>
# Artem Glechinsky: dsa <|endofstatement|>
# Artem Glechinsky: dfsd <|endofstatement|>
# Artem Glechinsky: asd <|endofstatement|>
# Artem Glechinsky: fsd <|endofstatement|>
# Artem Glechinsky: 124567655 <|endofstatement|>
# Artem Glechinsky: asdasdas <|endofstatement|>
# Artem Glechinsky: 3 <|endofstatement|>
# Artem Glechinsky: 4 <|endofstatement|>
# Artem Glechinsky: 1 <|endofstatement|>
# Artem Glechinsky: 2 <|endofstatement|>
# Artem Glechinsky: first one <|endofstatement|>
# Artem Glechinsky: 1 <|endofstatement|>
# Artem Glechinsky: 2 <|endofstatement|>
# Artem Glechinsky: 3 <|endofstatement|>
# Artem Glechinsky: 1 <|endofstatement|>
# Artem Glechinsky: asd <|endofstatement|>
# Artem Glechinsky: asd <|endofstatement|>
# Artem Glechinsky: as <|endofstatement|>
# Artem Glechinsky: asd <|endofstatement|>
#
# [{'id': 22484013, 'author_name': 'Syhapod', 'reply_to': 0, 'text': 'В полигон иди, тебе уже кидали', 'level': 0, 'time': 1675664948, 'answers': []}, {'id': 22485169, 'author_name': 'Котьмак из школы кота', 'reply_to': 0, 'text': 'Дарю:', 'level': 0, 'time': 1675668258, 'answers': []}, {'id': 22485197, 'author_name': 'Котьмак из школы кота', 'reply_to': 22485169, 'text': 'И в общей ленте не мусоришь, и за тем куда постишь следить не надо, и от лишних телодвижений по занесению тебя в чс окружающих избавляешь\nСплошные плюсы', 'level': 1, 'time': 1675668332, 'answers': []}, {'id': 23295777, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'zczxc', 'level': 0, 'time': 1678118312, 'answers': []}, {'id': 23299994, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'sdfsf', 'level': 0, 'time': 1678129933, 'answers': []}, {'id': 23299997, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'Apchi', 'level': 0, 'time': 1678129940, 'answers': []}, {'id': 23300181, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'dsa', 'level': 0, 'time': 1678130507, 'answers': []}, {'id': 23300405, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'dfsd', 'level': 0, 'time': 1678131210, 'answers': []}, {'id': 23300489, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'asd', 'level': 0, 'time': 1678131479, 'answers': []}, {'id': 23300495, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'fsd', 'level': 0, 'time': 1678131502, 'answers': []}, {'id': 23300508, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '124567655', 'level': 0, 'time': 1678131548, 'answers': []}, {'id': 23300509, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'asdasdas', 'level': 0, 'time': 1678131553, 'answers': []}, {'id': 23300540, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '3', 'level': 0, 'time': 1678131655, 'answers': []}, {'id': 23300541, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '4', 'level': 0, 'time': 1678131658, 'answers': []}, {'id': 23300561, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '1', 'level': 0, 'time': 1678131740, 'answers': []}, {'id': 23300563, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '2', 'level': 0, 'time': 1678131743, 'answers': []}, {'id': 23308743, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'first one', 'level': 0, 'time': 1678176639, 'answers': []}, {'id': 23308785, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '1', 'level': 0, 'time': 1678176737, 'answers': []}, {'id': 23308787, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '2', 'level': 0, 'time': 1678176739, 'answers': []}, {'id': 23308788, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '3', 'level': 0, 'time': 1678176742, 'answers': []}, {'id': 23308802, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': '1', 'level': 0, 'time': 1678176793, 'answers': []}, {'id': 23376470, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'asd', 'level': 0, 'time': 1678392734, 'answers': []}, {'id': 23376507, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'asd', 'level': 0, 'time': 1678392880, 'answers': []}, {'id': 23376515, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'as', 'level': 0, 'time': 1678392912, 'answers': []}, {'id': 23376549, 'author_name': 'Artem Glechinsky', 'reply_to': 0, 'text': 'asd', 'level': 0, 'time': 1678393097, 'answers': []}]

# %%
"""
    Метод получения новых комментариев со всех своих постов.
"""
await dtf.get_new_comments()
# Out:
# {1612676: [{'id': 23376594,
#    'author_name': 'Artem Glechinsky',
#    'reply_to': 0,
#    'text': 'asd',
#    'level': 0,
#    'time': 1678393322,
#    'answers': []}]}

# %%
"""
    Метод получения всех ответов на свои комментарии.
"""
await dtf.get_answers_on_my_comments()
# Out:
# {23308910: [],
#  23232478: [{'id': 23295261,
#    'author_name': 'Artem Glechinsky',
#    'reply_to': 23232478,
#    'text': 'фывфыв',
#    'level': 1,
#    'time': 1678117048,
#    'answers': []},
#   {'id': 23295938,
#    'author_name': 'Artem Glechinsky',
#    'reply_to': 23232478,
#    'text': 'ysasd a',
#    'level': 1,
#    'time': 1678118734,
#    'answers': []},
#   {'id': 23295997,
#    'author_name': 'Artem Glechinsky',
#    'reply_to': 23232478,
#    'text': 'xcv',
#    'level': 1,
#    'time': 1678118837,
#    'answers': []},
#   {'id': 23296896,
#    'author_name': 'Artem Glechinsky',
#    'reply_to': 23232478,
#    'text': 'sadsa',
#    'level': 1,
#    'time': 1678121318,
#    'answers': []}],
#  23232401: [{'id': 23300011,
#    'author_name': 'Artem Glechinsky',
#    'reply_to': 23232401,
#    'text': '124124113',
#    'level': 2,
#    'time': 1678129977,
#    'answers': []}],
#  22484144: [],
#  22484033: [{'id': 22484126,
#    'author_name': 'Syhapod',
#    'reply_to': 22484033,
#    'text': 'https://cmtt-ru.github.io/osnova-api/swaggerui/index.html#/Auth/postAuthQr\n\nНе нужна тут никакая дока, все описано и понятно, все ендпоинты примитивны\nЕщё есть вебхуки и вебсокеты, с ними все и так понятно должно быть',
#    'level': 2,
#    'time': 1675665328,
#    'answers': []}],
#  22483137: [],
#  22482537: [],
#  22482162: [{'id': 23232401,
#    'author_name': 'Серёжа Сысоев',
#    'reply_to': 22482162,
#    'text': 'api comment',
#    'level': 1,
#    'time': 1677871724,
#    'answers': []}]}

# %%
"""
    Метод получения дерева комментариев для конкретного комментария.
"""
res = await dtf.get_comment_tree(23369885)
print(res)
# Out:
# [{'id': 23369568, 'author_name': 'GodGaben', 'reply_to': 0, 'text': 'За Императора!', 'level': 0, 'time': 1678376021, 'answers': []}, {'id': 23369667, 'author_name': 'ХАНТЕР73', 'reply_to': 23369568, 'text': 'Zа того самого? (наброс)', 'level': 1, 'time': 1678376280, 'answers': []}, {'id': 23369885, 'author_name': 'Kotoyob Siskonovich', 'reply_to': 23369667, 'text': 'Дискредитируешь солцеликого сравнивая его с трупом на стуле?', 'level': 2, 'time': 1678376867, 'answers': []}, {'id': 23370374, 'author_name': 'Гимнокалициум', 'reply_to': 23369885, 'text': 'У нас за ересь пока не казнят. Пока.', 'level': 3, 'time': 1678378125, 'answers': []}, {'id': 23370001, 'author_name': 'Niksons', 'reply_to': 23369885, 'text': 'Стул или длинный стол, какая разница?', 'level': 3, 'time': 1678377242, 'answers': []}, {'id': 23370421, 'author_name': 'Kotoyob Siskonovich', 'reply_to': 23370374, 'text': 'Сходи в церковь и расскажи, что "Гагарин в космос летал и бога не видал". С немалым шансом набутылят как еретика', 'level': 4, 'time': 1678378243, 'answers': []}, {'id': 23370678, 'author_name': 'HTTP404', 'reply_to': 23370374, 'text': 'Но уже штрафуют.', 'level': 4, 'time': 1678378957, 'answers': []}, {'id': 23373454, 'author_name': 'Илья Васнецов', 'reply_to': 23370374, 'text': 'Ничего, в Беларуси уже начали)', 'level': 4, 'time': 1678384975, 'answers': []}, {'id': 23371923, 'author_name': 'Zomboss', 'reply_to': 23370421, 'text': 'Оскорблял чувства с особым цинизмом', 'level': 5, 'time': 1678382005, 'answers': []}]

# %%
"""Метод ответа/комментирования"""
# await dtf.reply_to_comment(entry_id, id_to_reply, msg)
# Out:
# 'Метод ответа/комментирования'

# %%
"""Метод получения новых уведомлений"""
await dtf.get_updates()
# Out:
# {'message': '',
#  'result': [{'id': 155764737,
#    'group_id': 245874347,
#    'type': 32,
#    'date': 1678394265,
#    'dateRFC': 'Thu, 09 Mar 2023 23:37:45 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky прокомментировал публикацию, на которую вы подписаны Этап авторизации + запрос пройден',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden?comment=23376871',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) прокомментировал публикацию, на которую вы подписаны [**Этап авторизации + запрос пройден**](https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden)'},
#   {'id': 155261509,
#    'group_id': 245596108,
#    'type': 32,
#    'date': 1678176808,
#    'dateRFC': 'Tue, 07 Mar 2023 11:13:28 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky прокомментировал публикацию, на которую вы подписаны Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23308814',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) прокомментировал публикацию, на которую вы подписаны [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)'},
#   {'id': 155261483,
#    'group_id': 245595983,
#    'type': 32,
#    'date': 1678176793,
#    'dateRFC': 'Tue, 07 Mar 2023 11:13:13 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky прокомментировал публикацию, на которую вы подписаны Этап авторизации + запрос пройден',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden?comment=23308802',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) прокомментировал публикацию, на которую вы подписаны [**Этап авторизации + запрос пройден**](https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden)'},
#   {'id': 155194220,
#    'group_id': 245532841,
#    'type': 32,
#    'date': 1678132076,
#    'dateRFC': 'Mon, 06 Mar 2023 22:47:56 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky прокомментировал публикацию, на которую вы подписаны Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23300670',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) прокомментировал публикацию, на которую вы подписаны [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)'},
#   {'id': 155194106,
#    'group_id': 245556056,
#    'type': 65536,
#    'date': 1678131994,
#    'dateRFC': 'Mon, 06 Mar 2023 22:46:34 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky положительно оценил вашу запись Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world',
#    'icon': 'like_up',
#    'color': 'green',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) положительно оценил вашу запись [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)'},
#   {'id': 155193789,
#    'group_id': 245533968,
#    'type': 32,
#    'date': 1678131743,
#    'dateRFC': 'Mon, 06 Mar 2023 22:42:23 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky прокомментировал публикацию, на которую вы подписаны Этап авторизации + запрос пройден',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden?comment=23300563',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) прокомментировал публикацию, на которую вы подписаны [**Этап авторизации + запрос пройден**](https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden)'},
#   {'id': 155192704,
#    'group_id': 245555104,
#    'type': 65536,
#    'date': 1678131488,
#    'dateRFC': 'Mon, 06 Mar 2023 22:38:08 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky положительно оценил вашу запись Этап авторизации + запрос пройден',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden',
#    'icon': 'like_up',
#    'color': 'green',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) положительно оценил вашу запись [**Этап авторизации + запрос пройден**](https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden)'},
#   {'id': 155188476,
#    'group_id': 245552553,
#    'type': 4,
#    'date': 1678129977,
#    'dateRFC': 'Mon, 06 Mar 2023 22:12:57 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky ответил на ваш комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23300011',
#    'icon': 'reply',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) ответил на ваш комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)',
#    'comment_text': '124124113'},
#   {'id': 155165076,
#    'group_id': 245539225,
#    'type': 4,
#    'date': 1678121318,
#    'dateRFC': 'Mon, 06 Mar 2023 19:48:38 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky ответил на ваш комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23296896',
#    'icon': 'reply',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) ответил на ваш комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)',
#    'comment_text': 'sadsa'},
#   {'id': 155157664,
#    'group_id': 245535279,
#    'type': 4,
#    'date': 1678118837,
#    'dateRFC': 'Mon, 06 Mar 2023 19:07:17 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky ответил на ваш комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23295997',
#    'icon': 'reply',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) ответил на ваш комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)',
#    'comment_text': 'xcv'},
#   {'id': 155157333,
#    'group_id': 245535072,
#    'type': 4,
#    'date': 1678118734,
#    'dateRFC': 'Mon, 06 Mar 2023 19:05:34 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky ответил на ваш комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23295938',
#    'icon': 'reply',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) ответил на ваш комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)',
#    'comment_text': 'ysasd a'},
#   {'id': 155152552,
#    'group_id': 245532850,
#    'type': 4,
#    'date': 1678117048,
#    'dateRFC': 'Mon, 06 Mar 2023 18:37:28 +0300',
#    'users': [{'id': 798935,
#      'name': 'Artem Glechinsky',
#      'avatar_url': 'https://leonardo.osnova.io/2b1829fb-5f49-494f-b193-7a4257bde6f0/'}],
#    'text': 'Artem Glechinsky ответил на ваш комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=23295261',
#    'icon': 'reply',
#    'color': 'blue',
#    'markdown': '[**Artem Glechinsky**](https://dtf.ru/u/798935-artem-glechinsky) ответил на ваш комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)',
#    'comment_text': 'фывфыв'},
#   {'id': 149485527,
#    'group_id': 227902420,
#    'type': 32,
#    'date': 1675668259,
#    'dateRFC': 'Mon, 06 Feb 2023 10:24:19 +0300',
#    'users': [{'id': 664956,
#      'name': 'Котьмак из школы кота',
#      'avatar_url': 'https://leonardo.osnova.io/ab5bba2f-1102-5dd8-bac6-2924e5149ccd/'}],
#    'text': 'Котьмак из школы кота и ещё один человек прокомментировали публикацию, на которую вы подписаны Этап авторизации + запрос пройден',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden?comment=22485169',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Котьмак из школы кота**](https://dtf.ru/u/664956-kotmak-iz-shkoly-kota) и ещё один человек прокомментировали публикацию, на которую вы подписаны [**Этап авторизации + запрос пройден**](https://dtf.ru/u/711777-serezha-sysoev/1612676-etap-avtorizacii-zapros-proyden)'},
#   {'id': 149479383,
#    'group_id': 227902615,
#    'type': 4,
#    'date': 1675665328,
#    'dateRFC': 'Mon, 06 Feb 2023 09:35:28 +0300',
#    'users': [{'id': 609517,
#      'name': 'Syhapod',
#      'avatar_url': 'https://leonardo.osnova.io/fead4364-fbe0-4a50-c94a-06c6027f741b/'}],
#    'text': 'Syhapod ответил на ваш комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=22484126',
#    'icon': 'reply',
#    'color': 'blue',
#    'markdown': '[**Syhapod**](https://dtf.ru/u/609517-syhapod) ответил на ваш комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)',
#    'comment_text': 'https://cmtt-ru.github.io/osnova-api/swaggerui/index.html#/Auth/postAuthQr\n\nНе нужна тут никакая дока, все описано и понятно, все ендпоинты примитивны\nЕщё есть вебхуки и вебсокеты, с ними все и так понятно должно быть'},
#   {'id': 149478851,
#    'group_id': 227891042,
#    'type': 32,
#    'date': 1675664935,
#    'dateRFC': 'Mon, 06 Feb 2023 09:28:55 +0300',
#    'users': [{'id': 609517,
#      'name': 'Syhapod',
#      'avatar_url': 'https://leonardo.osnova.io/fead4364-fbe0-4a50-c94a-06c6027f741b/'}],
#    'text': 'Syhapod и ещё 2 человека прокомментировали публикацию, на которую вы подписаны Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=22484009',
#    'icon': 'comment',
#    'color': 'blue',
#    'markdown': '[**Syhapod**](https://dtf.ru/u/609517-syhapod) и ещё 2 человека прокомментировали публикацию, на которую вы подписаны [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)'},
#   {'id': 149461027,
#    'group_id': 227890961,
#    'type': 2,
#    'date': 1675654957,
#    'dateRFC': 'Mon, 06 Feb 2023 06:42:37 +0300',
#    'users': [{'id': 578335,
#      'name': 'Necroflex небинарный',
#      'avatar_url': 'https://leonardo.osnova.io/957948ac-5c63-55e6-b2c2-2c0ffbb83922/'}],
#    'text': 'Necroflex небинарный положительно оценил комментарий к записи Hello world',
#    'url': 'https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world?comment=22482162',
#    'icon': 'like_up',
#    'color': 'green',
#    'markdown': '[**Necroflex небинарный**](https://dtf.ru/u/578335-necroflex-nebinarnyy) положительно оценил комментарий к записи [**Hello world**](https://dtf.ru/u/711777-serezha-sysoev/1612527-hello-world)'}]}

# %%
"""Метод получения количества новых уведомлений"""
await dtf.get_updates_count()
# Out:
# 1
